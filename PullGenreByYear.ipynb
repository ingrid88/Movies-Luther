# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
from collections import Counter
import pandas as pd

# %%
# Out:
# {'action': Counter({u'(1915)': 1,
#           u'(1916)': 1,
#           u'(1924)': 3,
#           u'(1925)': 1,
#           u'(1926)': 2,
#           u'(1927)': 1,
#           u'(1928)': 2,
#           u'(1930)': 1,
#           u'(1932)': 2,
#           u'(1933)': 1,
#           u'(1934)': 2,
#           u'(1935)': 3,
#           u'(1936)': 3,
#           u'(1937)': 2,
#           u'(1938)': 2,
#           u'(1939)': 2,
#           u'(1940)': 6,
#           u'(1941)': 3,
#           u'(1942)': 10,
#           u'(1943)': 6,
#           u'(1944)': 2,
#           u'(1945)': 3,
#           u'(1946)': 1,
#           u'(1947)': 4,
#           u'(1948)': 9,
#           u'(1949)': 3,
#           u'(1950)': 2,
#           u'(1951)': 7,
#           u'(1952)': 7,
#           u'(1953)': 5,
#           u'(1954)': 8,
#           u'(1955)': 8,
#           u'(1956)': 5,
#           u'(1957)': 8,
#           u'(1958)': 5,
#           u'(1959)': 3,
#           u'(1960)': 3,
#           u'(1961)': 8,
# ...

# %%
page = requests.get('http://www.imdb.com/search/title?at=0&genres=sci_fi&num_votes=1000,&sort=alpha&title_type=feature')

# %%
i = '1'
url = "http://www.imdb.com/search/title?amp=&at=0&genres=sci_fi&num_votes=1000,&sort=alpha&start="+str(i)+"&title_type=feature"
page = requests.get(url).text
print page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page,"lxml")
xx = soup.find_all(class_='year_type')
xx_yrs = [x.text for x in xx]

# from bs4 import BeautifulSoup
# soup = BeautifulSoup(html_doc, 'html.parser')

# %%
"http://www.imdb.com/search/title?amp=&at=0&genres=sci_fi&num_votes=1000,&sort=alpha&start=0&title_type=feature"
new_url = 'http://www.imdb.com/search/title?at=0&genres=sci_fi&num_votes=1000,&sort=alpha&title_type=feature'
          "http://www.imdb.com/search/title?at=0&amp;genres=sci_fi&amp;num_votes=1000,&amp;sort=alpha&amp;start=51&amp;title_type=feature
page = requests.get(new_url)
base_url = "http://www.imdb.com"
# next_page = soup.find(class_='pagination').find('a')['href']
new_url = base_url + next_page
# Out:
# '/search/title?at=0&genres=sci_fi&num_votes=1000,&sort=alpha&start=51&title_type=feature'

# %%
# Counter(xx_yrs)
print [1,2,3]+[12,3]
# Out:
# [1, 2, 3, 12, 3]

# %%
d = dict()
d["romance"]=romance_dict
d["sci_fi"]=scifi_dict
d["drama"]=drama_dict

# %%
d["romance"]=romance_dict
d["sci_fi"]=scifi_dict
d["drama"]=drama_dict

# %%
# Out:
# [Counter({u'(1915)': 1,
#           u'(1920)': 1,
#           u'(1922)': 1,
#           u'(1927)': 2,
#           u'(1928)': 2,
#           u'(1930)': 1,
#           u'(1931)': 2,
#           u'(1932)': 3,
#           u'(1933)': 4,
#           u'(1934)': 3,
#           u'(1935)': 4,
#           u'(1936)': 6,
#           u'(1937)': 6,
#           u'(1938)': 4,
#           u'(1939)': 7,
#           u'(1940)': 5,
#           u'(1941)': 8,
#           u'(1942)': 8,
#           u'(1943)': 6,
#           u'(1944)': 18,
#           u'(1945)': 12,
#           u'(1946)': 13,
#           u'(1947)': 14,
#           u'(1948)': 6,
#           u'(1949)': 4,
#           u'(1950)': 8,
#           u'(1951)': 2,
#           u'(1952)': 2,
#           u'(1953)': 4,
#           u'(1954)': 4,
#           u'(1955)': 6,
#           u'(1956)': 3,
#           u'(1957)': 3,
#           u'(1958)': 2,
#           u'(1959)': 10,
#           u'(1960)': 9,
#           u'(1961)': 7,
#           u'(1962)': 9,
# ...

# %%
# d = dict()
sm_d = {"war": 1007}
for k,v in sm_d.items():
    cat = []
    for i in range(1,v,50):
        url = "http://www.imdb.com/search/title?amp=&at=0&genres="+k+"&num_votes=1000,&sort=alpha&start="+str(i)+"&title_type=feature"
        page = requests.get(url).text
        soup = BeautifulSoup(page,"lxml")
        xx = soup.find_all(class_='year_type')
        xx_yrs = [x.text for x in xx]
        cat += xx_yrs
    d[k] = Counter(cat)

# %%
drama_dict = Counter(drama)

# %%
genres_table = pd.DataFrame.from_dict(d)

# %%
genres_table.fillna(0, inplace=True)

# %%
earlier = genres_table.iloc[20:70]
later = genres_table.iloc[80:-2]

# %%
genres_table
# Out:
#         action  adventure  animation  comedy  crime  drama  family  fantasy  \
# (1911)       0          1          0       0      0      1       0        1
# (1913)       0          0          0       0      1      2       0        1
# (1914)       0          1          0       1      0      1       0        0
# (1915)       1          1          0       0      1      3       0        0
# (1916)       1          1          0       0      0      1       0        0
# (1918)       0          0          0       0      0      1       0        0
# (1919)       0          1          0       4      0      4       0        1
# (1920)       0          1          0       2      1      5       0        1
# (1921)       0          1          0       2      0      7       1        2
# (1922)       0          1          0       1      1      2       2        1
# (1923)       0          1          0       4      0      5       2        0
# ...

# %%
genres_table.to_pickle('genre_yr_distribution.pkl')

# %%
genres_table.sum().sum()
# Out:
# 50092.0

# %%
sm_d
# Out:
# {'war': 1007}

# %%
d
# Out:
# {'action': Counter({u'(1915)': 1,
#           u'(1916)': 1,
#           u'(1924)': 3,
#           u'(1925)': 1,
#           u'(1926)': 2,
#           u'(1927)': 1,
#           u'(1928)': 2,
#           u'(1930)': 1,
#           u'(1932)': 2,
#           u'(1933)': 1,
#           u'(1934)': 2,
#           u'(1935)': 3,
#           u'(1936)': 3,
#           u'(1937)': 2,
#           u'(1938)': 2,
#           u'(1939)': 2,
#           u'(1940)': 6,
#           u'(1941)': 3,
#           u'(1942)': 10,
#           u'(1943)': 6,
#           u'(1944)': 2,
#           u'(1945)': 3,
#           u'(1946)': 1,
#           u'(1947)': 4,
#           u'(1948)': 9,
#           u'(1949)': 3,
#           u'(1950)': 2,
#           u'(1951)': 7,
#           u'(1952)': 7,
#           u'(1953)': 5,
#           u'(1954)': 8,
#           u'(1955)': 8,
#           u'(1956)': 5,
#           u'(1957)': 8,
#           u'(1958)': 5,
#           u'(1959)': 3,
#           u'(1960)': 3,
#           u'(1961)': 8,
# ...

# %%
res = earlier.T.corr(method='pearson').unstack().reset_index()
res.columns=["l1","l2","Corr"]
nres = res.sort_values(by='Corr',ascending=False)
toot = nres[(nres.Corr < 1) & (nres.Corr > .5) & (nres.l1 != "drama") & (nres.l2 != "drama")].sort_values(by="Corr",ascending=False)

# %%
int(toot.l1.iloc[0].lstrip("(").rstrip(")"))
# Out:
# 1938

# %%
earliers = earlier.reset_index()
earliers["yr"] = earliers["index"].apply(lambda x: x.lstrip("(").rstrip(")"))

# %%
earliers.drop("index",axis=1,inplace=True)

# %%
# earliers.set_index("yr",inplace=True)
earliers.T.corr().
# Out:
# yr        1933      1934      1935      1936      1937      1938      1939  \
# yr
# 1933  1.000000  0.944527  0.951701  0.934157  0.940976  0.959434  0.892759
# 1934  0.944527  1.000000  0.963020  0.954944  0.977438  0.972046  0.980305
# 1935  0.951701  0.963020  1.000000  0.953150  0.938375  0.938928  0.926353
# 1936  0.934157  0.954944  0.953150  1.000000  0.964076  0.974047  0.933459
# 1937  0.940976  0.977438  0.938375  0.964076  1.000000  0.988587  0.946286
# 1938  0.959434  0.972046  0.938928  0.974047  0.988587  1.000000  0.940273
# 1939  0.892759  0.980305  0.926353  0.933459  0.946286  0.940273  1.000000
# 1940  0.921703  0.957775  0.937487  0.936109  0.918882  0.939489  0.965523
# 1941  0.964598  0.948916  0.921175  0.955088  0.953140  0.971155  0.911032
# 1942  0.889157  0.934953  0.862469  0.892668  0.894784  0.912585  0.935864
# 1943  0.773684  0.835211  0.766129  0.825699  0.796481  0.820955  0.867766
# ...

# %%
res = earliers.T.corr(method='pearson').unstack().reset_index()
res.columns=["11","l2","Corr"]
nres = res.sort_values(by='Corr',ascending=False)
toot = nres[(nres.Corr < 1) & (nres.Corr > .5) & (nres.l1 != "drama") & (nres.l2 != "drama")].sort_values(by="Corr",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-272-8e9f2e3b1309> in <module>()
#       1
# ----> 2 res = earliers.T.corr(method='pearson').unstack().reset_index()
#       3 res.columns=["l1","l2","Corr"]
#       4 nres = res.sort_values(by='Corr',ascending=False)
#       5 toot = nres[(nres.Corr < 1) & (nres.Corr > .5) & (nres.l1 != "drama") & (nres.l2 != "drama")].sort_values(by="Corr",ascending=False)
#
# /Users/ingrid/anaconda/envs/py27/lib/python2.7/site-packages/pandas/core/series.pyc in reset_index(self, level, drop, name, inplace)
#     939         else:
#     940             df = self.to_frame(name)
# --> 941             return df.reset_index(level=level, drop=drop)
#     942
#     943     def __unicode__(self):
#
# ...

# %%
toot["i1"] = toot.l1.apply(lambda x: x.lstrip("(").rstrip(")"))
toot["i2"] = toot.l2.apply(lambda x: x.lstrip("(").rstrip(")"))
toot.drop(["l1","l2"],axis=1)
# Out:
#           Corr    i1    i2
# 254   0.988587  1938  1937
# 205   0.988587  1937  1938
# 1584  0.984869  1964  1967
# 1731  0.984869  1967  1964
# 1735  0.983964  1967  1968
# 1784  0.983964  1968  1967
# 1223  0.983112  1957  1956
# 1174  0.983112  1956  1957
# 1988  0.983011  1972  1971
# 1939  0.983011  1971  1972
# 1420  0.980570  1961  1953
# 1028  0.980570  1953  1961
# 2041  0.980390  1973  1974
# 2090  0.980390  1974  1973
# 56    0.980305  1934  1939
# 301   0.980305  1939  1934
# 2495  0.980257  1982  1978
# 2299  0.980257  1978  1982
# 2345  0.980218  1979  1978
# 2296  0.980218  1978  1979
# 1022  0.979140  1953  1955
# 1120  0.979140  1955  1953
# 54    0.977438  1934  1937
# 201   0.977438  1937  1934
# 1881  0.975873  1970  1964
# 1587  0.975873  1964  1970
# 2399  0.974661  1980  1982
# 2497  0.974661  1982  1980
# 2398  0.974413  1980  1981
# 2447  0.974413  1981  1980
# ...        ...   ...   ...
# 2371  0.616103  1980  1954
# 1097  0.616103  1954  1980
# ...

# %%
genres_table.T.corr()
# Out:
#           (1911)    (1913)    (1914)    (1915)    (1916)    (1918)    (1919)  \
# (1911)  1.000000  0.592157  0.318182  0.301511  0.318182  0.443203  0.306774
# (1913)  0.592157  1.000000  0.098693  0.463713  0.098693  0.699854  0.491630
# (1914)  0.318182  0.098693  1.000000  0.489956  0.318182  0.443203  0.635460
# (1915)  0.301511  0.463713  0.489956  1.000000  0.489956  0.801784  0.351264
# (1916)  0.318182  0.098693  0.318182  0.489956  1.000000  0.443203  0.197212
# (1918)  0.443203  0.699854  0.443203  0.801784  0.443203  1.000000  0.621545
# (1919)  0.306774  0.491630  0.635460  0.351264  0.197212  0.621545  1.000000
# (1920)  0.576859  0.795506  0.342997  0.491233  0.226066  0.773906  0.706494
# (1921)  0.543275  0.748336  0.543275  0.639362  0.280400  0.900986  0.805407
# (1922)  0.223669  0.562318  0.047088  0.156174 -0.129492  0.333914  0.499398
# (1923)  0.129492  0.460079  0.482654  0.331869  0.129492  0.605218  0.890972
# ...

# %%
g_sub = genres_table.drop(["drama","comedy","thriller","romance","action","crime","horror"],axis=1)
g_sub2 = earlier.drop(["drama","comedy","thriller","romance"],axis=1) #"action","crime","horror","adventure"

# %%
import seaborn as sns
# sns.axes_style({'xtick.major.size': 10,'xtick.minor.size': 10})
f, ax = plt.subplots(figsize=(20, 15))
la = later.drop("drama",axis=1).sort_values(by="thriller")
sns.heatmap(la) #earlier[["crime","war","mystery"]]

# %%
summary = pd.DataFrame(genres_table.sum())
summary.columns=["Count"]
summary.sort_values(by="Count",ascending=False).T
# Out:
#        drama  comedy  thriller  romance  action  crime  horror  adventure  \
# Count  11776    7803      5193     4799    3662   3479    2741       2306
#
#        mystery  sci_fi  fantasy  family   war  animation  western
# Count     1783    1710     1508    1199  1007        634      492

# %%
import numpy as np
f = plt.figure()
plt.title('Adventure Action Thriller', color='black')
np.log(genres_table[["action","adventure","sci_fi"]]).plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
# plt.legend(loc="upper left", bbox_to_anchor=(1,1))
f = plt.figure()

plt.title('Genres Over the Years', color='black')
genres_table[["romance","horror","sci_fi"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

f = plt.figure()

plt.title('Genres Over the Years', color='black')
genres_table[["action","adventure","sci_fi"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# genres_table.plot()

f = plt.figure()
plt.title('Genres Over the Years: Mystery & Fantasy Animation Western', color='black')
genres_table[["mystery","fantasy","animation","western"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# genres_ta


f = plt.figure()
plt.title('Genres Over the Years: Crime & Mystery', color='black')
genres_table[["crime","mystery"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

f = plt.figure()
plt.title('Genres Over the Years: All', color='black')
genres_table.plot(kind='area',ax=f.gca(),stacked=True,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

f = plt.figure()
plt.title('Fantasy Animation', color='black')
genres_table[["fantasy","animation"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# f = plt.figure()
# plt.title('Romance SciFi', color='black')
# genres_table[["romance","sci_fi"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.show()

# f = plt.figure()
# plt.title('Adventure Action Thriller', color='black')
# genres_table[["adventure","action","thriller"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.show()

# f = plt.figure()
# plt.title('Adventure Action Thriller', color='black')
# genres_table[["adventure","action","thriller"]].plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.show()

f = plt.figure()
plt.title('Genres Over the Years: Crime, Mystery, Horror', color='black')
np.log(genres_table[["crime","mystery","horror"]]).plot(kind='area',ax=f.gca(),stacked=False,alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
genres_table
# Out:
#         action  adventure  animation  comedy  crime  drama  family  fantasy  \
# (1911)       0          1          0       0      0      1       0        1
# (1913)       0          0          0       0      1      2       0        1
# (1914)       0          1          0       1      0      1       0        0
# (1915)       1          1          0       0      1      3       0        0
# (1916)       1          1          0       0      0      1       0        0
# (1918)       0          0          0       0      0      1       0        0
# (1919)       0          1          0       4      0      4       0        1
# (1920)       0          1          0       2      1      5       0        1
# (1921)       0          1          0       2      0      7       1        2
# (1922)       0          1          0       1      1      2       2        1
# (1923)       0          1          0       4      0      5       2        0
# ...

# %%
scifi_dict = Counter(scifi)

# %%
romance_dict = Counter(romance)

# %%
# romance_dict

# %%
ncategories = {"animation":634,"comedy": 7803, "crime":  3479, "horror": 2741,"adventure": 2306,"thriller": 5193,"action":3662, "mystery":1783, "western":492, "family":1199, "fantasy":1508 }
categories = {'romance': 4799,'drama': 11826,'sci_fi': 1710,"animation":634,"comedy": 7803, "crime":  3479, "horror": 2741,"adventure": 2306,"thriller": 5193,"action":3662, "mystery":1783, "western":492, "family":1199, "fantasy":1508 }

# %%
d = dict()
d["1"] = ncategories
d["2"] = categories

# %%
d
# Out:
# {'1': {'action': 3662,
#   'adventure': 2306,
#   'animation': 634,
#   'comedy': 7803,
#   'crime': 3479,
#   'family': 1199,
#   'fantasy': 1508,
#   'horror': 2741,
#   'mystery': 1783,
#   'thriller': 5193,
#   'western': 492},
#  '2': {'action': 3662,
#   'adventure': 2306,
#   'animation': 634,
#   'comedy': 7803,
#   'crime': 3479,
#   'drama': 11826,
#   'family': 1199,
#   'fantasy': 1508,
#   'horror': 2741,
#   'mystery': 1783,
#   'romance': 4799,
#   'sci_fi': 1710,
#   'thriller': 5193,
#   'western': 492}}

# %%
for k,v in ncategories.items():
    print k
# Out:
# family
# horror
# fantasy
# adventure
# thriller
# mystery
# crime
# animation
# action
# comedy
# western

# %%
d = list()

# %%
d
# Out:
# []

# %%
"f" = 3
# Out:
#   File "<ipython-input-89-61fad717367f>", line 1
#     "f" = 3
# SyntaxError: can't assign to literal
